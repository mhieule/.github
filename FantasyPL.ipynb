# %% [markdown]
# <a href="https://colab.research.google.com/github/mhieule/.github/blob/main/FantasyPL.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Import all necessary libraries

# %%
import requests
import json
import pandas as pd
import numpy as np
from pprint import pprint

# %% [markdown]
# # Make a GET request from the API endpoint

# %%
"""
Base url
"""

base_url = 'https://fantasy.premierleague.com/api/'
url = base_url+'bootstrap-static/'

"""
Perform GET request
"""

r_json = requests.get(url).json()
pprint(r_json, indent=2, depth=1, compact=True)
# Out:
# { 'element_stats': [...],
#   'element_types': [...],
#   'elements': [...],
#   'events': [...],
#   'game_settings': {...},
#   'phases': [...],
#   'teams': [...],
#   'total_players': 8723192}

# %% [markdown]
# # Find out the important JSON keys aka "elements", "element_type" and "teams"
# TODO: Expand the model by finding possible important keys among the rest

# %%
r_json.keys()
# Out:
# dict_keys(['events', 'game_settings', 'phases', 'teams', 'total_players', 'elements', 'element_stats', 'element_types'])

# %% [markdown]
# # Build DataFrame from the API request response

# %%
elements_df = pd.DataFrame(r_json['elements'])
elements_types_df = pd.DataFrame(r_json['element_types'])
teams_df = pd.DataFrame(r_json['teams'])

# %% [markdown]
# ## Players DataFrame

# %%
print(elements_df.columns)
elements_df.head()
# Out:
# Index(['chance_of_playing_next_round', 'chance_of_playing_this_round', 'code',
#        'cost_change_event', 'cost_change_event_fall', 'cost_change_start',
#        'cost_change_start_fall', 'dreamteam_count', 'element_type', 'ep_next',
#        'ep_this', 'event_points', 'first_name', 'form', 'id', 'in_dreamteam',
#        'news', 'news_added', 'now_cost', 'photo', 'points_per_game',
#        'second_name', 'selected_by_percent', 'special', 'squad_number',
#        'status', 'team', 'team_code', 'total_points', 'transfers_in',
#        'transfers_in_event', 'transfers_out', 'transfers_out_event',
#        'value_form', 'value_season', 'web_name', 'minutes', 'goals_scored',
#        'assists', 'clean_sheets', 'goals_conceded', 'own_goals',
#        'penalties_saved', 'penalties_missed', 'yellow_cards', 'red_cards',
#        'saves', 'bonus', 'bps', 'influence', 'creativity', 'threat',
#        'ict_index', 'starts', 'expected_goals', 'expected_assists',
#        'expected_goal_involvements', 'expected_goals_conceded',
#        'influence_rank', 'influence_rank_type', 'creativity_rank',
#        'creativity_rank_type', 'threat_rank', 'threat_rank_type',
#        'ict_index_rank', 'ict_index_rank_type',
#        'corners_and_indirect_freekicks_order',
#        'corners_and_indirect_freekicks_text', 'direct_freekicks_order',
#        'direct_freekicks_text', 'penalties_order', 'penalties_text',
#        'expected_goals_per_90', 'saves_per_90', 'expected_assists_per_90',
#        'expected_goal_involvements_per_90', 'expected_goals_conceded_per_90',
#        'goals_conceded_per_90', 'now_cost_rank', 'now_cost_rank_type',
#        'form_rank', 'form_rank_type', 'points_per_game_rank',
#        'points_per_game_rank_type', 'selected_rank', 'selected_rank_type',
#        'starts_per_90', 'clean_sheets_per_90'],
#       dtype='object')
#    chance_of_playing_next_round  chance_of_playing_this_round    code  \
# 0                         100.0                         100.0  232223
# 1                           NaN                           NaN   58822
# 2                           0.0                           0.0  153256
# 3                           NaN                           NaN  438098
# 4                           NaN                           NaN  226597
#
#    cost_change_event  cost_change_event_fall  cost_change_start  \
# 0                  0                       0                  0
# 1                  0                       0                  0
# 2                  0                       0                  0
# 3                  0                       0                  0
# 4                  0                       0                  0
#
#    cost_change_start_fall  dreamteam_count  element_type ep_next  ...  \
# 0                       0                0             4     1.5  ...
# 1                       0                0             2     1.5  ...
# 2                       0                0             3     0.0  ...
# 3                       0                0             3     2.6  ...
# 4                       0                0             2     2.8  ...
#
#   now_cost_rank  now_cost_rank_type form_rank form_rank_type  \
# 0           436                  68       460             43
# 1           554                 154       289             90
# 2           362                 206       417            145
# 3           137                  89       634            270
# 4           255                  31       242             86
#
#    points_per_game_rank  points_per_game_rank_type selected_rank  \
# 0                   460                         43           199
# 1                   289                         90           251
# 2                   417                        145           439
# 3                   634                        270           416
# 4                   242                         86             7
#
#   selected_rank_type  starts_per_90 clean_sheets_per_90
# 0                 38            0.0                 0.0
# 1                 92            0.0                 0.0
# 2                150            0.0                 0.0
# 3                136            0.0                 0.0
# 4                  3            0.0                 0.0
#
# [5 rows x 88 columns]

# %% [markdown]
# ### Lite Players DataFrame

# %%
# Handpick the important attributes of players
lite_players_df = elements_df[['second_name','first_name','team','element_type','form','selected_by_percent','now_cost','total_points','value_season']]
lite_players_df.head()

# Map players to their position and change the column name to 'position'
lite_players_df['element_type'] = lite_players_df.element_type.map(elements_types_df.set_index('id').singular_name)
lite_players_df.rename(columns={'element_type': 'position'})
lite_players_df.head()

# Map players to their team
lite_players_df['team'] = lite_players_df.team.map(teams_df.set_index('id').name)
lite_players_df.head(5)
# Out:
# <ipython-input-6-9f4d85aedfcb>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   lite_players_df['element_type'] = lite_players_df.element_type.map(elements_types_df.set_index('id').singular_name)
# <ipython-input-6-9f4d85aedfcb>:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   lite_players_df['team'] = lite_players_df.team.map(teams_df.set_index('id').name)
#             second_name first_name     team element_type form  \
# 0               Balogun    Folarin  Arsenal      Forward  0.0
# 1          Alves Soares     Cédric  Arsenal     Defender  0.0
# 2                Elneny    Mohamed  Arsenal   Midfielder  0.0
# 3       Ferreira Vieira      Fábio  Arsenal   Midfielder  0.0
# 4  dos Santos Magalhães    Gabriel  Arsenal     Defender  1.0
#
#   selected_by_percent  now_cost  total_points value_season
# 0                 0.7        45             0          0.0
# 1                 0.4        40             0          0.0
# 2                 0.1        45             0          0.0
# 3                 0.1        55             0          0.0
# 4                31.4        50             1          0.2

# %% [markdown]
# ## Teams DataFrame

# %%
print(teams_df.columns)
teams_df.head()
# Out:
# Index(['code', 'draw', 'form', 'id', 'loss', 'name', 'played', 'points',
#        'position', 'short_name', 'strength', 'team_division', 'unavailable',
#        'win', 'strength_overall_home', 'strength_overall_away',
#        'strength_attack_home', 'strength_attack_away', 'strength_defence_home',
#        'strength_defence_away', 'pulse_id'],
#       dtype='object')
#    code  draw  form  id  loss         name  played  points  position  \
# 0     3     0  None   1     0      Arsenal       0       0         0
# 1     7     0  None   2     0  Aston Villa       0       0         0
# 2    91     0  None   3     0  Bournemouth       0       0         0
# 3    94     0  None   4     0    Brentford       0       0         0
# 4    36     0  None   5     0     Brighton       0       0         0
#
#   short_name  ...  team_division unavailable  win  strength_overall_home  \
# 0        ARS  ...           None       False    0                   1230
# 1        AVL  ...           None       False    0                   1115
# 2        BOU  ...           None       False    0                   1060
# 3        BRE  ...           None       False    0                   1125
# 4        BHA  ...           None       False    0                   1165
#
#    strength_overall_away  strength_attack_home  strength_attack_away  \
# 0                   1285                  1250                  1250
# 1                   1175                  1130                  1190
# 2                   1095                  1050                  1100
# 3                   1205                  1120                  1220
# 4                   1210                  1120                  1200
#
#    strength_defence_home  strength_defence_away  pulse_id
# 0                   1210                   1320         1
# 1                   1100                   1160         2
# 2                   1060                   1090       127
# 3                   1130                   1190       130
# 4                   1210                   1240       131
#
# [5 rows x 21 columns]

# %% [markdown]
# # Exploratory Analysis on Players Data
#
# Here we will extract the most significant statistics on players data which was preprocessed in the last step. For the time being, there will only be most valueable players, positions and teams.
#
# **TODO**: Advanced filters and sortings on multiple performance indices. \\
# **TODO**: Plot the correlation between ... and point \\
# **TODO**: Plot the performances of players to compare \\

# %% [markdown]
# ## Most valueable players

# %%
# Use astype() to convert the values in the column "value_season" to be floats
lite_players_df['value_season'] = lite_players_df.value_season.astype(float)

# Use sort_values() to sort the values of the players
lite_players_df.sort_values('value_season', ascending=False).head(10)
# Out:
# <ipython-input-8-a4c92970b8ec>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   lite_players_df['value_season'] = lite_players_df.value_season.astype(float)
#                second_name first_name            team element_type  form  \
# 449                 Varane    Raphaël         Man Utd     Defender  14.0
# 308                   Leno      Bernd          Fulham   Goalkeeper  12.0
# 455            Wan-Bissaka      Aaron         Man Utd     Defender  12.0
# 418              Hernandez    Rodrigo        Man City   Midfielder  13.0
# 238                 Disasi       Axel         Chelsea     Defender  11.0
# 243               Andersen    Joachim  Crystal Palace     Defender   9.0
# 456                  Onana      André         Man Utd   Goalkeeper   9.0
# 574  Leite de Souza Junior    Emerson           Spurs     Defender   8.0
# 257               Mitchell     Tyrick  Crystal Palace     Defender   8.0
# 304                   Diop       Issa          Fulham     Defender   8.0
#
#     selected_by_percent  now_cost  total_points  value_season
# 449                 2.3        50            14           2.8
# 308                 8.2        45            12           2.7
# 455                 1.8        45            12           2.7
# 418                 5.8        55            13           2.4
# 238                 1.6        50            11           2.2
# 243                 1.9        45             9           2.0
# 456                28.1        50             9           1.8
# 574                 1.1        45             8           1.8
# 257                 0.6        45             8           1.8
# 304                 0.8        45             8           1.8

# %% [markdown]
# ## Most valueable positions

# %%
# Create a copy of lite_players_df in which the players that have value <= 0 are removed
positive_lite_players_df = lite_players_df.loc[lite_players_df.value_season > 0]

# Pivot table to aggregate after position
pivot = positive_lite_players_df.pivot_table(index='element_type', values = 'value_season', aggfunc = np.mean).reset_index()
pivot.sort_values('value_season', ascending=False)
# Out:
#   element_type  value_season
# 2   Goalkeeper      0.720000
# 0     Defender      0.605618
# 1      Forward      0.591892
# 3   Midfielder      0.438235

# %% [markdown]
# ## Most valueable teams

# %%
# Pivot table to aggregate after team
pivot_team = positive_lite_players_df.pivot_table(index=['team'], values = 'value_season', aggfunc = np.mean).reset_index()
pivot_team.sort_values('value_season', ascending=False)
# Out:
#               team  value_season
# 7   Crystal Palace      1.050000
# 9           Fulham      0.969231
# 12        Man City      0.793750
# 13         Man Utd      0.780000
# 4         Brighton      0.662500
# 14       Newcastle      0.656250
# 17           Spurs      0.538462
# 0          Arsenal      0.515385
# 11           Luton      0.490909
# 6          Chelsea      0.473333
# 18        West Ham      0.471429
# 3        Brentford      0.466667
# 2      Bournemouth      0.413333
# 1      Aston Villa      0.370000
# 8          Everton      0.369231
# 16   Sheffield Utd      0.366667
# 15   Nott'm Forest      0.360000
# 19          Wolves      0.320000
# 10       Liverpool      0.313333
# 5          Burnley      0.280000

# %% [markdown]
# ## Most valueable player within teams

# %%
# Pivot table to aggregate after team to find out the max value player within each team
pivot_team_max = positive_lite_players_df.pivot_table(index=['team'], values = 'value_season', aggfunc = np.max).reset_index()
pivot_team_max.sort_values('value_season', ascending=False)

#Merge with the original dataframe to find the names and other stats of the Team MVPs
team_mvp_df = pivot_team_max.merge(lite_players_df, how="left", on=['team', 'value_season'])
team_mvp_df.sort_values('value_season', ascending=False)
# Out:
#               team  value_season            second_name first_name  \
# 29         Man Utd           2.8                 Varane    Raphaël
# 25          Fulham           2.7                   Leno      Bernd
# 28        Man City           2.4              Hernandez    Rodrigo
# 12         Chelsea           2.2                 Disasi       Axel
# 13  Crystal Palace           2.0               Andersen    Joachim
# 34           Spurs           1.8  Leite de Souza Junior    Emerson
# 31       Newcastle           1.7                 Barnes     Harvey
# 30       Newcastle           1.7                   Isak  Alexander
# 0          Arsenal           1.5                Nketiah      Eddie
# 3        Brentford           1.5                  Wissa      Yoane
# 27           Luton           1.5                 Morris    Carlton
# 4         Brighton           1.4              Estupiñán     Pervis
# 5         Brighton           1.4                  March      Solly
# 35        West Ham           1.4                 Souček      Tomáš
# 26       Liverpool           1.1                   Díaz       Luis
# 32   Nott'm Forest           1.1                Awoniyi      Taiwo
# 2      Bournemouth           1.1                Solanke    Dominic
# 1      Aston Villa           1.1                  Diaby     Moussa
# 33   Sheffield Utd           0.9            Foderingham        Wes
# 36          Wolves           0.6                Sarabia      Pablo
# 20         Everton           0.4                  Onana     Amadou
# 14         Everton           0.4               Doucouré  Abdoulaye
# 6          Burnley           0.4                 Cullen       Josh
# 7          Burnley           0.4                 Foster       Lyle
# 8          Burnley           0.4                  Berge     Sander
# 9          Burnley           0.4                Amdouni       Zeki
# 10         Burnley           0.4               Trafford      James
# 11         Burnley           0.4               Koleosho       Luca
# 15         Everton           0.4                 Garner      James
# 21         Everton           0.4              Patterson     Nathan
# 16         Everton           0.4                  Gueye    Idrissa
# 17         Everton           0.4                  Iwobi       Alex
# 19         Everton           0.4                 Maupay       Neal
# 24         Everton           0.4                  Young     Ashley
# 23         Everton           0.4              Tarkowski      James
# 22         Everton           0.4               Pickford     Jordan
# 18         Everton           0.4                  Keane    Michael
#
#    element_type  form selected_by_percent  now_cost  total_points
# 29     Defender  14.0                 2.3        50            14
# 25   Goalkeeper  12.0                 8.2        45            12
# 28   Midfielder  13.0                 5.8        55            13
# 12     Defender  11.0                 1.6        50            11
# 13     Defender   9.0                 1.9        45             9
# 34     Defender   8.0                 1.1        45             8
# 31   Midfielder  11.0                 3.6        65            11
# 30      Forward  13.0                21.6        76            13
# 0       Forward   8.0                 4.1        55             8
# 3       Forward   9.0                 5.5        60             9
# 27      Forward   8.0                 1.3        55             8
# 4      Defender   7.0                54.1        50             7
# 5    Midfielder   9.0                 3.3        65             9
# 35   Midfielder   7.0                 1.2        50             7
# 26   Midfielder   8.0                 6.7        75             8
# 32      Forward   7.0                 0.6        65             7
# 2       Forward   7.0                 3.0        65             7
# 1    Midfielder   7.0                 7.3        65             7
# 33   Goalkeeper   4.0                 0.3        45             4
# 36   Midfielder   3.0                 0.1        50             3
# 20   Midfielder   2.0                 0.3        50             2
# 14   Midfielder   2.0                 0.2        55             2
# 6    Midfielder   2.0                 0.1        50             2
# 7       Forward   2.0                 0.3        50             2
# 8    Midfielder   2.0                 0.2        50             2
# 9       Forward   2.0                 0.2        55             2
# 10   Goalkeeper   2.0                 1.1        45             2
# 11   Midfielder   2.0                 0.0        50             2
# 15   Midfielder   2.0                 0.0        50             2
# 21     Defender   2.0                 0.2        45             2
# 16   Midfielder   2.0                 0.1        50             2
# 17   Midfielder   2.0                 0.9        55             2
# 19      Forward   2.0                 1.3        50             2
# 24     Defender   2.0                 0.7        45             2
# 23     Defender   2.0                 2.1        45             2
# 22   Goalkeeper   2.0                15.3        45             2
# 18     Defender   2.0                 0.3        45             2
